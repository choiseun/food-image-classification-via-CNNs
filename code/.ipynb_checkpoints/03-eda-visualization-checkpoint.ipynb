# %% [markdown]
# # Pre-Processing & Modeling

# %% [markdown]
# ### Pre-Processing

# %% [markdown]
# Referenced: https://git.generalassemb.ly/DSIR-Lancelot/8.04-lesson-cnns/blob/master/solution-code/02-cnn.ipynb

# %%
# Imports
import os
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D

# For reproducibility
np.random.seed(42)

# %%
# Create a list for each food class
burgers_list = []
hotdogs_list = []
pizza_list = []
tacos_list = []
sushi_list = []

# Create a list of all food class lists
class_list = [burgers_list, hotdogs_list, pizza_list, tacos_list, sushi_list]

# Create a list of strings containing the food classes
food_classes = ['burgers', 'hotdogs', 'pizza', 'tacos', 'sushi']

# %%
# Define a function that converts all images
# Image target size: multiple of 32, consider 256x256, 384x384, or 512x512
def image_converter(food_list, food_class):
    food_path = f'../images/{food_class}/'
    for file in os.listdir(food_path):
        try:
            image = load_img(food_path + file, target_size=(224, 224))
            image_arr = img_to_array(image) / 255
            food_list.append(image_arr)
        except:
            print(f'Error for file: {file}')
    print(f'{len(food_list)} pictures have been converted for {food_class}.')

# %%
# Iterate through the image_converter function for each food class
my_index = 0
for food_class in class_list:
    image_converter(food_class, food_classes[my_index])
    my_index += 1
# Out:
# Error for file: .DS_Store
# 282 pictures have been converted for burgers.
# Error for file: .DS_Store
# 253 pictures have been converted for hotdogs.
# Error for file: .DS_Store
# 276 pictures have been converted for pizza.
# Error for file: .DS_Store
# 260 pictures have been converted for tacos.
# Error for file: .DS_Store
# 268 pictures have been converted for sushi.

# %% [markdown]
# ### Modeling

# %% [markdown]
# #### Null Model

# %%
# Baseline accuracy of majority class
282/(282+253+276+260+268)
# Out:
# 0.210604929051531

# %% [markdown]
# **Interpretation:** The baseline accuracy of the majority class (i.e. burgers) is 21.06%. At a minimum, the production model must have an accuracy score that exceeds the null model.

# %% [markdown]
# #### Model 1: CNN made from scratch

# %%
# Define X
X = burgers_list + hotdogs_list + pizza_list + tacos_list + sushi_list
X = np.array(X)
X.shape
# Out:
# (1339, 224, 224, 3)

# %%
# Define y
# 0 for burgers, 1 for hotdogs, 2 for pizza, 3 for tacos, 4 for sushi
y = [0]*282 + [1]*253 + [2]*276 + [3]*260 + [4]*268
y = np.array(y)
y = to_categorical(y)
y.shape
# Out:
# (1339, 5)

# %%
# Train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Reshape
X_train = np.array(X_train)
X_test = np.array(X_test)

# Check shape
print(f'X train shape: {X_train[0].shape}')
print(f'y train shape: {y_train.shape}')
# Out:
# X train shape: (224, 224, 3)
# y train shape: (1004, 5)

# %%
# Referenced: https://github.com/clairehester/face-mask-detector/blob/main/code/02_face_mask_detector.ipynb
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
aug = ImageDataGenerator(
    rotation_range=20,
    zoom_range=0.15,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.15,
    horizontal_flip=True,
    fill_mode='nearest'
)

# %%
# Model architecture
model = Sequential([
    Conv2D(64, (3,3), activation='relu', input_shape=(X_train[0].shape)),
    MaxPooling2D(pool_size=(2,2)),
    Conv2D(64, (4,4), activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Flatten(),
    Dense(64, activation='relu'),
    # Dropout layer
    Dense(5, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', 
              metrics=['acc']) # 'Recall', 'Precision'

# Fit the model
results = model.fit(aug.flow(X_train, y_train, batch_size=8), validation_data=(X_test, y_test),
                   batch_size=8, epochs=10) # Try 10 epochs
# Out:
# Epoch 1/10
# 126/126 [==============================] - 162s 1s/step - loss: 2.6468 - acc: 0.1706 - val_loss: 1.6087 - val_acc: 0.2388
# Epoch 2/10
# 126/126 [==============================] - 132s 1s/step - loss: 1.6101 - acc: 0.2240 - val_loss: 1.6089 - val_acc: 0.2060
# Epoch 3/10
# 126/126 [==============================] - 134s 1s/step - loss: 1.6089 - acc: 0.2011 - val_loss: 1.6079 - val_acc: 0.2239
# Epoch 4/10
# 126/126 [==============================] - 153s 1s/step - loss: 1.6081 - acc: 0.2006 - val_loss: 1.6086 - val_acc: 0.2119
# Epoch 5/10
# 126/126 [==============================] - 135s 1s/step - loss: 1.6086 - acc: 0.2104 - val_loss: 1.6078 - val_acc: 0.2119
# Epoch 6/10
# 126/126 [==============================] - 159s 1s/step - loss: 1.6071 - acc: 0.2291 - val_loss: 1.5974 - val_acc: 0.2806
# Epoch 7/10
# 126/126 [==============================] - 169s 1s/step - loss: 1.5990 - acc: 0.2758 - val_loss: 1.5609 - val_acc: 0.2687
# Epoch 8/10
# 126/126 [==============================] - 132s 1s/step - loss: 1.5809 - acc: 0.2804 - val_loss: 1.5353 - val_acc: 0.2716
# Epoch 9/10
# 126/126 [==============================] - 152s 1s/step - loss: 1.5657 - acc: 0.2938 - val_loss: 1.5480 - val_acc: 0.2896
# Epoch 10/10
# 126/126 [==============================] - 179s 1s/step - loss: 1.5500 - acc: 0.2859 - val_loss: 1.5668 - val_acc: 0.2597

# %%
# Check model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 222, 222, 64)      1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 111, 111, 64)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 108, 108, 64)      65600
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 54, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 186624)            0
# _________________________________________________________________
# dense (Dense)                (None, 64)                11944000
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 325
# =================================================================
# Total params: 12,011,717
# Trainable params: 12,011,717
# Non-trainable params: 0
# _________________________________________________________________

# %%
# from sklearn.metrics import confusion_matrix

# predIdxs = model.predict(X_test, batch_size=8)

# cm = confusion_matrix(y_test.argmax(axis=1), predIdxs)

# plt.style.use("ggplot")
# plt.imshow(cm, cmap=plt.cm.Blues, interpolation='nearest')
# plt.xlabel("Predicted labels")
# plt.ylabel("True labels")
# plt.xticks(np.arange(len(cm)), ['Worn Incorrectly', 'With Mask', 'Without Mask'], rotation=45, size='large')
# plt.yticks(np.arange(len(cm)), ['Worn Incorrectly', 'With Mask', 'Without Mask'], rotation=45, size='large')
# plt.title('Confusion matrix ')
# plt.grid(None)
# plt.colorbar()
# for i in range(len(cm)):
#     for j in range(len(cm)):
#         plt.text(j, i, cm[i, j], ha='center', va='center', size='large')
# plt.show()

# %% [markdown]
# #### Model 2: CNN pre-trained on EfficientNet

# %%
# Referenced: https://colab.research.google.com/github/keras-team/keras-io/blob/master/examples/vision/ipynb/image_classification_efficientnet_fine_tuning.ipynb#scrollTo=G2iZMMXDMEb_
from tensorflow.keras.layers.experimental import preprocessing
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers

# %%
img_augmentation = Sequential([
    preprocessing.RandomRotation(factor=0.15),
    preprocessing.RandomTranslation(height_factor=0.1, width_factor=0.1),
    preprocessing.RandomFlip(),
    preprocessing.RandomContrast(factor=0.1),
    ],
    name='img_augmentation',
)

# %%
import tensorflow as tf
from tensorflow.keras.layers.experimental import preprocessing
from tensorflow.keras.applications import EfficientNetB0

# %%
inputs = layers.Input(shape=X_train[0].shape)
x = img_augmentation(inputs)
new_model = EfficientNetB0(include_top=False, input_tensor=x, weights='imagenet')

new_model.trainable = False

x = layers.GlobalAveragePooling2D(name='avg_pool')(new_model.output)
x = layers.BatchNormalization()(x)

top_dropout_rate = 0.2
x = layers.Dropout(top_dropout_rate, name='top_dropout')(x)
outputs = layers.Dense(5, activation='softmax', name='pred')(x)

new_model = tf.keras.Model(inputs, outputs, name='EfficientNet')
optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)
new_model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['acc'])

# Fit the model
new_results = new_model.fit(X_train, y_train, validation_data=(X_test, y_test),
                   batch_size=8, epochs=10) # Change # of epochs to 10-15
# Out:
# Epoch 1/10
# 126/126 [==============================] - 107s 782ms/step - loss: 3.2581 - acc: 0.2098 - val_loss: 1.9821 - val_acc: 0.2119
# Epoch 2/10
# 126/126 [==============================] - 128s 1s/step - loss: 2.7499 - acc: 0.1921 - val_loss: 1.6819 - val_acc: 0.2000
# Epoch 3/10
# 126/126 [==============================] - 134s 1s/step - loss: 2.3297 - acc: 0.1881 - val_loss: 1.6631 - val_acc: 0.2000
# Epoch 4/10
# 126/126 [==============================] - 119s 943ms/step - loss: 2.2924 - acc: 0.1894 - val_loss: 1.7036 - val_acc: 0.2000
# Epoch 5/10
# 126/126 [==============================] - 117s 934ms/step - loss: 2.1426 - acc: 0.2227 - val_loss: 1.7609 - val_acc: 0.2000
# Epoch 6/10
# 126/126 [==============================] - 97s 768ms/step - loss: 1.9894 - acc: 0.1952 - val_loss: 1.9592 - val_acc: 0.2119
# Epoch 7/10
# 126/126 [==============================] - ETA: 0s - loss: 1.9540 - acc: 0.1794

# %% [markdown]
# ### Post-Modeling

# %%
# probas = np.array([[0.4, 0.1, 0.5],[0.7, 0.2, 0.1],[0.3, 0.4, 0.3]])
probas = model.predict(X_test)
labels = np.argmax(probas, axis=-1)    
print(labels)

# %%
from sklearn.metrics import plot_confusion_matrix

# %%
# Predictions
y_preds = model.predict(X_test)
y_preds.shape

# %%
# Plot confusion matrix
plot_confusion_matrix(model, y_preds, y_test)
# labels=['burger', 'hotdog', 'pizza', 'tacos', 'sushi']

# %%
# Try 1-2 changes to hidden layers - look for improvements
# If yes, there were low hanging fruit worth my time
# If no, go collect more images (start with image augmentation in keras)
# Keras directory and my data setup should work perfectly

# %%
# Use Google Colab to run this

# %%
# Need more hidden layers/neurons

# %%
# Precision/recall

# %%
# Image Data Augmentation

# %%
# Analysis of misclassifications

# %% [markdown]
# ### Exploratory Data Analysis (EDA)

# %%
from PIL import Image

# %%
# Histogram of image dimensions
im = Image.open('../images/burgers/burgers_1.jpg')
im.size[0]
# Out:
# 3024

# %%
def image_size_retriever(food_list, food_class):
    image_dict = {}
    file_path = f'../images/{food_class}'
    for file in os.listdir(file_path):
        try:
            image = Image.open(file_path + file)
            image_dict[image.size[0]] = image_dict[image.size[1]]
        except:
            print(f'Error for file: {file}')
    return image_dict

# %%
my_index = 0
for food_class in class_list:
    image_size_retriever(food_class, food_classes[my_index])
    my_index += 1
# Out:
# Error for file: burgers_15.jpg
# Error for file: burgers_29.jpg
# Error for file: burgers_198.jpg
# Error for file: burgers_239.jpg
# Error for file: burgers_211.jpg
# Error for file: burgers_205.jpg
# Error for file: burgers_204.jpg
# Error for file: burgers_210.jpg
# Error for file: burgers_238.jpg
# Error for file: burgers_199.jpg
# Error for file: burgers_28.jpg
# Error for file: burgers_14.jpg
# Error for file: burgers_14.png
# Error for file: burgers_16.png
# Error for file: burgers_206.jpg
# Error for file: burgers_212.jpg
# Error for file: burgers_213.jpg
# Error for file: burgers_207.jpg
# Error for file: burgers_17.png
# Error for file: burgers_13.png
# Error for file: sushi_230.jpg
# Error for file: sushi_280.jpg
# Error for file: sushi_257.jpg
# Error for file: sushi_243.jpg
# Error for file: sushi_46.jpg
# Error for file: sushi_52.jpg
# Error for file: sushi_91.jpg
# Error for file: sushi_109.jpg
# Error for file: sushi_121.jpg
# Error for file: sushi_135.jpg
# Error for file: sushi_134.jpg
# Error for file: sushi_120.jpg
# Error for file: sushi_108.jpg
# Error for file: sushi_90.jpg
# Error for file: sushi_84.jpg
# Error for file: sushi_242.jpg
# Error for file: sushi_256.jpg
# Error for file: sushi_281.jpg
# Error for file: sushi_283.jpg
# Error for file: sushi_268.jpg
# Error for file: sushi_240.jpg
# Error for file: sushi_254.jpg
# Error for file: sushi_79.jpg
# Error for file: sushi_51.jpg
# Error for file: sushi_45.jpg
# Error for file: sushi_92.jpg
# Error for file: sushi_86.jpg
# Error for file: sushi_136.jpg
# Error for file: sushi_122.jpg
# Error for file: sushi_123.jpg
# Error for file: sushi_137.jpg
# Error for file: sushi_87.jpg
# Error for file: sushi_93.jpg
# Error for file: sushi_44.jpg
# Error for file: sushi_50.jpg
# Error for file: sushi_78.jpg
# Error for file: sushi_255.jpg
# Error for file: sushi_241.jpg
# Error for file: sushi_269.jpg
# Error for file: sushi_282.jpg
# Error for file: sushi_286.jpg
# Error for file: sushi_245.jpg
# Error for file: sushi_251.jpg
# Error for file: sushi_279.jpg
# Error for file: sushi_40.jpg
# Error for file: sushi_68.jpg
# Error for file: sushi_97.jpg
# Error for file: sushi_83.jpg
# Error for file: sushi_133.jpg
# Error for file: sushi_126.jpg
# Error for file: sushi_132.jpg
# Error for file: sushi_82.jpg
# Error for file: sushi_96.jpg
# Error for file: sushi_69.jpg
# Error for file: sushi_41.jpg
# Error for file: sushi_278.jpg
# Error for file: sushi_250.jpg
# Error for file: sushi_244.jpg
# Error for file: sushi_287.jpg
# Error for file: sushi_291.jpg
# Error for file: sushi_285.jpg
# Error for file: sushi_252.jpg
# Error for file: sushi_246.jpg
# Error for file: sushi_43.jpg
# Error for file: sushi_57.jpg
# Error for file: sushi_80.jpg
# Error for file: sushi_124.jpg
# Error for file: sushi_130.jpg
# Error for file: sushi_118.jpg
# Error for file: sushi_119.jpg
# Error for file: sushi_131.jpg
# Error for file: sushi_125.jpg
# Error for file: sushi_95.jpg
# Error for file: sushi_81.jpg
# Error for file: sushi_56.jpg
# Error for file: sushi_42.jpg
# Error for file: sushi_247.jpg
# Error for file: sushi_253.jpg
# Error for file: sushi_284.jpg
# Error for file: sushi_290.jpg

# %%
def image_converter(food_list, food_class):
    food_path = f'../images/{food_class}/'
    for file in os.listdir(food_path):
        try:
            image = load_img(food_path + file, target_size=(384, 384))
            image_arr = img_to_array(image) / 255
            food_list.append(image_arr)
        except:
            print(f'Error for file: {file}')
    print(f'{len(food_list)} pictures have been converted for {food_class}.')

# %%
my_index = 0
for food_class in class_list:
    image_converter(food_class, food_classes[my_index])
    my_index += 1

# %%
class_list = [burgers_list, hotdogs_list, pizza_list, tacos_list, sushi_list]

# %%
food_classes = ['burgers', 'hotdogs', 'pizza', 'tacos', 'sushi']
